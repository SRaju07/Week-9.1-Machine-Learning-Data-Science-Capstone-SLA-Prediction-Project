# %%
from Feature_Selection import RFE_class

# %%
import pandas as pd

# %%
dataset = pd.read_csv(
            r"D:\python1\Week-9.1-Machine-Learning-Data-Science-Capstone-SLA-Prediction-Project\2.Data preprocessing\preprocessed_data.csv"
        )

# %%
dataset
# Out:
#      Incident_ID     Incident_Type  Priority Assigned_Department  \
# 0      INC100000    Network Outage       Low       Security Team
# 1      INC100001  Database Failure       Low      Database Admin
# 2      INC100002      Server Crash    Medium      Database Admin
# 3      INC100003  Database Failure  Critical        Network Team
# 4      INC100004      Server Crash  Critical       Security Team
# ...          ...               ...       ...                 ...
# 1195   INC101195   Application Bug  Critical       Security Team
# 1196   INC101196   Security Breach       Low        Network Team
# 1197   INC101197    Network Outage    Medium          IT Support
# 1198   INC101198   Application Bug    Medium          IT Support
# 1199   INC101199   Application Bug  Critical          IT Support
#
#            Location    Status       Resolution_Type  Resolution_Time_Hours  \
# 0     Data Center B  Resolved                Reboot                   18.0
# 1     Remote Site 1  Resolved                Reboot                   35.0
# 2     Remote Site 2    Closed         Patch Applied                   72.0
# 3     Remote Site 1  Resolved                Reboot                   36.0
# 4       Head Office  Resolved     Configuration Fix                   28.0
# ...             ...       ...                   ...                    ...
# 1195  Remote Site 2  Resolved  Hardware Replacement                   47.0
# 1196  Data Center B  Resolved                Reboot                   25.0
# 1197  Data Center B  Resolved         Patch Applied                   19.0
# 1198    Head Office    Closed         Patch Applied                   60.0
# 1199  Data Center A  Resolved  Hardware Replacement                   20.0
#
#       Hour  Day  Month  SLA_Limit  SLA_Breached
# 0        4    6      3         24             0
# 1       20    3      1         24             0
# 2        1    2      1         12             1
# 3        3    5      7          4             1
# 4        1    4      2          4             1
# ...    ...  ...    ...        ...           ...
# 1195    13    4     10          4             1
# 1196    17    4      1         24             1
# 1197     5    3      6         12             1
# 1198    17    3      9         12             1
# 1199    16    0      2          4             1
#
# [1200 rows x 13 columns]

# %%
result=RFE_class.Result()
# Out:
# ============================================================
# Running RFE using: LogisticRegression
# ============================================================
# Selected Features:
# ['Resolution_Time_Hours', 'SLA_Limit', 'Incident_ID_INC100006', 'Incident_ID_INC100007', 'Incident_ID_INC100062', 'Incident_ID_INC100151', 'Incident_ID_INC100210', 'Incident_ID_INC100219', 'Incident_ID_INC100246', 'Incident_ID_INC100305', 'Incident_ID_INC100498', 'Incident_ID_INC100531', 'Incident_ID_INC100559', 'Incident_ID_INC100635', 'Incident_ID_INC100680', 'Incident_ID_INC100695', 'Incident_ID_INC100721', 'Incident_ID_INC100727', 'Incident_ID_INC100729', 'Incident_ID_INC101120']
#
# ============================================================
# Running RFE using: SVC
# ============================================================
# Selected Features:
# ['Resolution_Time_Hours', 'SLA_Limit', 'Incident_ID_INC100006', 'Incident_ID_INC100007', 'Incident_ID_INC100041', 'Incident_ID_INC100062', 'Incident_ID_INC100151', 'Incident_ID_INC100197', 'Incident_ID_INC100219', 'Incident_ID_INC100305', 'Incident_ID_INC100499', 'Incident_ID_INC100531', 'Incident_ID_INC100559', 'Incident_ID_INC100635', 'Incident_ID_INC100680', 'Incident_ID_INC100695', 'Incident_ID_INC100727', 'Incident_ID_INC100734', 'Incident_ID_INC101120', 'Incident_ID_INC101190']
#
# ============================================================
# Running RFE using: RandomForestClassifier
# ============================================================
# Selected Features:
# ['Resolution_Time_Hours', 'Hour', 'Day', 'Month', 'SLA_Limit', 'Incident_Type_Database Failure', 'Incident_Type_Server Crash', 'Priority_High', 'Priority_Low', 'Priority_Medium', 'Assigned_Department_DevOps', 'Assigned_Department_IT Support', 'Assigned_Department_Network Team', 'Location_Data Center B', 'Location_Remote Site 1', 'Location_Remote Site 2', 'Status_Resolved', 'Resolution_Type_Hardware Replacement', 'Resolution_Type_Reboot', 'Resolution_Type_Security Mitigation']
#
# ============================================================
# Running RFE using: DecisionTreeClassifier
# ============================================================
# Selected Features:
# ['Resolution_Time_Hours', 'SLA_Limit', 'Incident_ID_INC100006', 'Incident_ID_INC100007', 'Incident_ID_INC100008', 'Incident_ID_INC100009', 'Incident_ID_INC100010', 'Incident_ID_INC100647', 'Incident_ID_INC100648', 'Incident_ID_INC100649', 'Incident_ID_INC100651', 'Incident_ID_INC100652', 'Incident_ID_INC100653', 'Incident_ID_INC100656', 'Incident_ID_INC100657', 'Incident_ID_INC100658', 'Incident_ID_INC100659', 'Incident_ID_INC100661', 'Incident_ID_INC100663', 'Incident_ID_INC100667']
#
# FINAL RESULTS:
#
#                  Logistic SVM_Linear   SVM_RBF  Decision    Random
# RFE_Logistic         0.98   0.983333  0.963333  0.996667      0.99
# RFE_SVC              0.98   0.983333  0.963333  0.996667  0.996667
# RFE_DecisionTree     0.98   0.983333  0.913333       1.0  0.986667
# RFE_RandomForest     0.99   0.996667  0.986667  0.996667  0.996667
#
# Best RFE Method: RFE_DecisionTree
# Best Model: Decision
# Best Accuracy: 1.0
